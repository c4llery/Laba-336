# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Лабораторная работа 336. Опыт Франка-Герца

# %% [markdown]
# ### 2 V:

# %%
v_2v = np.array([46.5, 44.2, 41.7, 39.7, 39.0, 37.4, 34.6, 32, 28.5, 27.3, 26.2, 25.4])
i_2v = np.array([49, 52, 56, 54, 53, 49, 40, 34, 22, 18, 18, 23])
v2 = dict(zip(v_2v, i_2v))

# %% [markdown]
# ### 3V:

# %%
v_3v = np.array([45.5, 44.3, 42.1, 40.9, 39.4, 36.7, 34.1, 31.3, 29.5, 28.5, 26.2, 26.2, 25.7, 25.3, 25, 24.7, 23.8])
i_3v = np.array([47, 50, 52, 53, 50, 42, 34, 25, 19, 15, 12, 11, 13, 18, 21, 24, 27])
v3 = dict(zip(v_3v, i_3v))

# %% [markdown]
# ### 4V:

# %%
v_4v = np.array([46.4, 45, 43.6, 42.3, 40.7, 41.7, 40.3, 40, 38.7, 35.6, 33.5, 32.2, 29.9, 29.2, 28.3, 27.7, 26.5, 26.7, 25.9, 25.4, 24.9])
i_4v = np.array([38, 42, 45, 46, 46, 46, 45, 45, 41, 32, 25, 20, 12, 10, 8, 6, 5, 6, 10, 13, 19])
v4 = dict(zip(v_4v, i_4v))

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.scatter(v_3v, i_3v, label="3В") # задаём лэйбл графика
ax.scatter(v_4v, i_4v, label="4В") # задаём лэйбл графика
ax.legend(loc=0) # отображаем легенду в оптимальном положении (параметр loc = 0)
ax
# Out:
# <AxesSubplot:>

# %%
data = {'V1, В': [23.8, 24.9],
        'V2, В': [43.6, 43.6],
        'Разница, В': [43.6-23.8, 43.6 - 24.9]
       }
df = pd.DataFrame(data, columns = ['V1, В', 'V2, В', 'Разница, В'], index=['3В', '4В'])
df
# Out:
#     V1, В  V2, В  Разница, В
# 3В   23.8   43.6        19.8
# 4В   24.9   43.6        18.7

# %% [markdown]
# $
# \Delta\bar{V}=\frac{\Delta V_{1}+\Delta V_{2}}{2}\\
# \Delta\bar{V}=19.25B\\
# \sigma=4В\\
# $
# $$
# E_{\text{стат}}=(19.25\pm4)\text{В}
# $$

# %% [markdown]
# ### Динамический режим

# %%
from IPython.display import Image
print('2V')
Image("2V.jpg", width=920, height=640)
# Out:
# 2V

# %%
print('3V')
Image("3V.jpg", width=920, height=640)
# Out:
# 3V

# %%
print('4V')
Image("4V.jpg", width=920, height=640)
# Out:
# 4V

# %%
import pandas as pd

# %%
data = {'V1, дел': [-1.1, -1.2, -1.4],
        'V2, дел': [0.9, 0.7, 0.6],
        'Разница, дел': [2, 1.9, 2]
       }
df = pd.DataFrame(data, columns = ["V1, дел", "V2, дел", "Разница, дел"], index=["2В", '3В', '4В'])
df
# Out:
#     V1, дел  V2, дел  Разница, дел
# 2В     -1.1      0.9           2.0
# 3В     -1.2      0.7           1.9
# 4В     -1.4      0.6           2.0

# %% [markdown]
# $
# \Delta\bar{V}=\frac{\sum_{k=1}^{3}\triangle V_{k}}{3}\\\\\\\\\\
# \varDelta\bar{V}=1.96\text{дел}\\\\\\\\\\\\
# \sigma_1=0.4 дел\\
# \sigma_2=0.05 дел\\\
# $
# $$
# \Delta V=(1.96\pm0.45)\text{дел}\Rightarrow\Delta V=(19.6\pm4.5)\text{В}
# $$
# $$
# E_{\text{дин}}=(19.6\pm4.5)\text{эВ}
# $$
